# %%
import pandas as pd
import numpy as np

# %%
plantas=pd.read_csv('/content/plant_growth_data.csv')
plantas
# Out:
#     Soil_Type  Sunlight_Hours Water_Frequency Fertilizer_Type  Temperature  \
# 0        loam        5.192294       bi-weekly        chemical    31.719602
# 1       sandy        4.033133          weekly         organic    28.919484
# 2        loam        8.892769       bi-weekly            none    23.179059
# 3        loam        8.241144       bi-weekly            none    18.465886
# 4       sandy        8.374043       bi-weekly         organic    18.128741
# ..        ...             ...             ...             ...          ...
# 188     sandy        5.652000           daily            none    28.000000
# 189      clay        7.528000          weekly        chemical    30.500000
# 190      loam        4.934000       bi-weekly            none    24.500000
# 191     sandy        8.273000           daily         organic    27.900000
# 192      clay        6.732000          weekly            none    21.700000
#
#       Humidity  Growth_Milestone
# 0    61.591861                 0
# ...

# %%
plantas.describe()
# Out:
#        Sunlight_Hours  Temperature    Humidity  Growth_Milestone
# count      193.000000   193.000000  193.000000        193.000000
# mean         6.826484    25.076087   58.098927          0.497409
# std          1.599509     5.354170   12.631799          0.501294
# min          4.033133    15.200000   30.567682          0.000000
# 25%          5.477000    20.637095   49.300000          0.000000
# 50%          6.833290    25.912336   59.182806          0.000000
# 75%          8.241144    29.757938   69.100000          1.000000
# max          9.913903    34.810103   79.648240          1.000000

# %%
plantas["Soil_Type"].value_counts()
# Out:
# Soil_Type
# clay     67
# sandy    64
# loam     62
# Name: count, dtype: int64

# %%
plantas["Soil_Type"]=plantas["Soil_Type"].replace("clay",1)
plantas["Soil_Type"]=plantas["Soil_Type"].replace("loam",2)
plantas["Soil_Type"]=plantas["Soil_Type"].replace("sandy",3)
plantas
# Out:
# /tmp/ipython-input-8-443787114.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   plantas["Soil_Type"]=plantas["Soil_Type"].replace("sandy",3)
#      Soil_Type  Sunlight_Hours Water_Frequency Fertilizer_Type  Temperature  \
# 0            2        5.192294       bi-weekly        chemical    31.719602
# 1            3        4.033133          weekly         organic    28.919484
# 2            2        8.892769       bi-weekly            none    23.179059
# 3            2        8.241144       bi-weekly            none    18.465886
# 4            3        8.374043       bi-weekly         organic    18.128741
# ..         ...             ...             ...             ...          ...
# ...

# %%
plantas
# Out:
#     Soil_Type  Sunlight_Hours Water_Frequency Fertilizer_Type  Temperature  \
# 0        loam        5.192294       bi-weekly        chemical    31.719602
# 1       sandy        4.033133          weekly         organic    28.919484
# 2        loam        8.892769       bi-weekly            none    23.179059
# 3        loam        8.241144       bi-weekly            none    18.465886
# 4       sandy        8.374043       bi-weekly         organic    18.128741
# ..        ...             ...             ...             ...          ...
# 188     sandy        5.652000           daily            none    28.000000
# 189      clay        7.528000          weekly        chemical    30.500000
# 190      loam        4.934000       bi-weekly            none    24.500000
# 191     sandy        8.273000           daily         organic    27.900000
# 192      clay        6.732000          weekly            none    21.700000
#
#       Humidity  Growth_Milestone
# 0    61.591861                 0
# ...

# %%
plantas["Water_Frequency"].value_counts()
# Out:
# Water_Frequency
# daily        74
# bi-weekly    60
# weekly       59
# Name: count, dtype: int64

# %%
plantas["Water_Frequency"]=plantas["Water_Frequency"].replace("daily",1)
plantas["Water_Frequency"]=plantas["Water_Frequency"].replace("bi-weekly",2)
plantas["Water_Frequency"]=plantas["Water_Frequency"].replace("weekly",3)
plantas
# Out:
# /tmp/ipython-input-10-2799077856.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   plantas["Water_Frequency"]=plantas["Water_Frequency"].replace("weekly",3)
#      Soil_Type  Sunlight_Hours  Water_Frequency Fertilizer_Type  Temperature  \
# 0            2        5.192294                2        chemical    31.719602
# 1            3        4.033133                3         organic    28.919484
# 2            2        8.892769                2            none    23.179059
# 3            2        8.241144                2            none    18.465886
# 4            3        8.374043                2         organic    18.128741
# ..         ...             ...              ...             ...          ...
# ...

# %%
plantas["Fertilizer_Type"].value_counts()
# Out:
# Fertilizer_Type
# none        74
# chemical    65
# organic     54
# Name: count, dtype: int64

# %%
plantas["Fertilizer_Type"]=plantas["Fertilizer_Type"].replace("none",1)
plantas["Fertilizer_Type"]=plantas["Fertilizer_Type"].replace("chemical",2)
plantas["Fertilizer_Type"]=plantas["Fertilizer_Type"].replace("organic",3)
plantas
# Out:
# /tmp/ipython-input-12-399902938.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   plantas["Fertilizer_Type"]=plantas["Fertilizer_Type"].replace("organic",3)
#      Soil_Type  Sunlight_Hours  Water_Frequency  Fertilizer_Type  Temperature  \
# 0            2        5.192294                2                2    31.719602
# 1            3        4.033133                3                3    28.919484
# 2            2        8.892769                2                1    23.179059
# 3            2        8.241144                2                1    18.465886
# 4            3        8.374043                2                3    18.128741
# ..         ...             ...              ...              ...          ...
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.pairplot(plantas,hue="Growth_Milestone")

# %%
X=plantas[["Water_Frequency",	"Fertilizer_Type","Temperature",	"Humidity"]]
y=plantas["Growth_Milestone"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.svm import SVC

# %%
svC=SVC(kernel="linear",random_state=0)
#svC=SVC(kernel="poly",random_state=0)
#svC=SVC(kernel="rbf",random_state=0)
#svC=SVC(kernel="sigmoid",random_state=0)

# %%
svC.fit(X_train,y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
y_predTest=svC.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
mx=confusion_matrix(y_test,y_predTest)
mx
# Out:
# array([[18, 10],
#        [13, 17]])

# %%
sns.heatmap(mx,annot=True)
# Out:
# <Axes: >

# %%
print(classification_report(y_test,y_predTest))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.64      0.61        28
#            1       0.63      0.57      0.60        30
#
#     accuracy                           0.60        58
#    macro avg       0.61      0.60      0.60        58
# weighted avg       0.61      0.60      0.60        58
