# %%
#biblioteca para manejo los datos
import pandas as pd

# %%
aviones=pd.read_csv('/content/On_Time_On_Time_Performance_2015_2ac.csv',sep=";")

# %%
aviones.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate UniqueCarrier  \
# 0  2015        1      2          23          1  23/02/2015            AS
# 1  2015        1      2          15          7  15/02/2015            AS
# 2  2015        1      2          22          7  22/02/2015            AS
# 3  2015        1      2          10          2  10/02/2015            OO
# 4  2015        1      2           8          7   8/02/2015            AS
#
#    AirlineID Carrier TailNum  ...  Div4WheelsOff  Div4TailNum  Div5Airport  \
# 0      19930      AS  N796AS  ...            NaN          NaN          NaN
# 1      19930      AS  N708AS  ...            NaN          NaN          NaN
# 2      19930      AS  N706AS  ...            NaN          NaN          NaN
# 3      20304      OO  N912EV  ...            NaN          NaN          NaN
# 4      19930      AS  N765AS  ...            NaN          NaN          NaN
#
#    Div5AirportID Div5AirportSeqID Div5WheelsOn Div5TotalGTime  \
# ...

# %%
aviones.sample(100)
# Out:
#        Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate UniqueCarrier  \
# 3690   2015        1      2          19          4  19/02/2015            HA
# 20965  2015        1      2          15          7  15/02/2015            EV
# 9083   2015        1      2          19          4  19/02/2015            HA
# 12930  2015        1      2          24          2  24/02/2015            WN
# 7240   2015        1      2          20          5  20/02/2015            MQ
# ...     ...      ...    ...         ...        ...         ...           ...
# 18414  2015        1      2          24          2  24/02/2015            WN
# 19562  2015        1      2          28          6  28/02/2015            WN
# 15442  2015        1      2          26          4  26/02/2015            EV
# 21104  2015        1      2          24          2  24/02/2015            UA
# 8180   2015        1      2          19          4  19/02/2015            DL
#
# ...

# %%
aviones.describe()
# Out:
#           Year  Quarter    Month    DayofMonth     DayOfWeek     AirlineID  \
# count  22139.0  22139.0  22139.0  22139.000000  22139.000000  22139.000000
# mean    2015.0      1.0      2.0     15.332084      3.820227  20070.142554
# std        0.0      0.0      0.0      7.952555      1.934776    361.607617
# min     2015.0      1.0      2.0      1.000000      1.000000  19393.000000
# 25%     2015.0      1.0      2.0      9.000000      2.000000  19790.000000
# 50%     2015.0      1.0      2.0     16.000000      4.000000  20304.000000
# 75%     2015.0      1.0      2.0     22.000000      5.000000  20366.000000
# max     2015.0      1.0      2.0     28.000000      7.000000  21171.000000
#
#           FlightNum  OriginAirportID  OriginAirportSeqID  OriginCityMarketID  \
# count  22139.000000     22139.000000        2.213900e+04        22139.000000
# mean    2934.425448     12585.142464        1.258517e+06        31743.712905
# ...

# %%
print(aviones.dtypes.to_string())
# Out:
# Year                      int64
# Quarter                   int64
# Month                     int64
# DayofMonth                int64
# DayOfWeek                 int64
# FlightDate               object
# UniqueCarrier            object
# AirlineID                 int64
# Carrier                  object
# TailNum                  object
# FlightNum                 int64
# OriginAirportID           int64
# OriginAirportSeqID        int64
# OriginCityMarketID        int64
# Origin                   object
# OriginCityName           object
# OriginState              object
# OriginStateFips           int64
# OriginStateName          object
# OriginWac                 int64
# DestAirportID             int64
# DestAirportSeqID          int64
# DestCityMarketID          int64
# Dest                     object
# DestCityName             object
# DestState                object
# DestStateFips             int64
# DestStateName            object
# DestWac                   int64
# ...

# %%
aviones.shape
# Out:
# (22139, 109)

# %%
#filtramos la columnas que necesitamos
avionesS=aviones[["ArrTime","ArrDelay","ArrDelayMinutes","DepTime","DepDelay","DepDelayMinutes"]]
avionesS.head()
# Out:
#    ArrTime  ArrDelay  ArrDelayMinutes  DepTime  DepDelay  DepDelayMinutes
# 0     1128         3                3     1052        -8                0
# 1     1151        26               26     1130        30               30
# 2     1610        22               22     1540        16               16
# 3     2315        87               87     2220        75               75
# 4     1550         2                2     1530         6                6

# %%
avionesS=avionesS[avionesS["DepDelay"]>0]
avionesS.sample(100)
# Out:
#        ArrTime  ArrDelay  ArrDelayMinutes  DepTime  DepDelay  DepDelayMinutes
# 6729      1125        32               32     1036        42               42
# 18788     1238        27               27     1119        12               12
# 9472      2032         2                2     1938         3                3
# 6137      1511       123              123     1237        21               21
# 2862      1608        42               42     1523        58               58
# ...        ...       ...              ...      ...       ...              ...
# 746       1157         2                2     1114         7                7
# 7123      1639         5                5     1448        18               18
# 19429     1342         2                2     1339         9                9
# 12988       52       164              164     2340       161              161
# 10377     1410         3                3     1313        13               13
#
# [100 rows x 6 columns]

# %%
avionesS=avionesS.drop_duplicates()
avionesS
# Out:
#        ArrTime  ArrDelay  ArrDelayMinutes  DepTime  DepDelay  DepDelayMinutes
# 1         1151        26               26     1130        30               30
# 2         1610        22               22     1540        16               16
# 3         2315        87               87     2220        75               75
# 4         1550         2                2     1530         6                6
# 5         1603        15               15     1545        21               21
# ...        ...       ...              ...      ...       ...              ...
# 22134     1231        47               47      933        54               54
# 22135     2136        48               48     1852        57               57
# 22136     2106        49               49     1459        38               38
# 22137     1931        51               51     1658        57               57
# 22138     1523        51               51     1020        40               40
#
# [16302 rows x 6 columns]

# %%
#estadística de la data
avionesS.describe()
# Out:
#             ArrTime      ArrDelay  ArrDelayMinutes       DepTime  \
# count  16371.000000  16371.000000     16371.000000  16371.000000
# mean    1586.602468     40.852300        40.852300   1526.321056
# std      488.533955     54.024471        54.024471    445.270365
# min        1.000000      1.000000         1.000000      1.000000
# 25%     1255.000000     10.000000        10.000000   1207.000000
# 50%     1639.000000     23.000000        23.000000   1547.000000
# 75%     1947.000000     51.000000        51.000000   1856.000000
# max     2400.000000   1251.000000      1251.000000   2400.000000
#
#            DepDelay  DepDelayMinutes
# count  16371.000000     16371.000000
# mean      39.646143        39.646143
# std       52.388581        52.388581
# min        1.000000         1.000000
# 25%       10.000000        10.000000
# 50%       23.000000        23.000000
# 75%       49.000000        49.000000
# max     1250.000000      1250.000000

# %%
#correlación lineal
avionesS.corr()
# Out:
#                   ArrTime  ArrDelay  ArrDelayMinutes   DepTime  DepDelay  \
# ArrTime          1.000000 -0.013901        -0.013901  0.698144 -0.004848
# ArrDelay        -0.013901  1.000000         1.000000  0.051693  0.963152
# ArrDelayMinutes -0.013901  1.000000         1.000000  0.051693  0.963152
# DepTime          0.698144  0.051693         0.051693  1.000000  0.066278
# DepDelay        -0.004848  0.963152         0.963152  0.066278  1.000000
# DepDelayMinutes -0.004848  0.963152         0.963152  0.066278  1.000000
#
#                  DepDelayMinutes
# ArrTime                -0.004848
# ArrDelay                0.963152
# ArrDelayMinutes         0.963152
# DepTime                 0.066278
# DepDelay                1.000000
# DepDelayMinutes         1.000000

# %%
avionesS.plot(kind="scatter",x="ArrDelay",y="DepDelay")
# Out:
# <Axes: xlabel='ArrDelay', ylabel='DepDelay'>

# %%
avionesS.plot(kind="scatter",x="DepTime",y="ArrTime")
# Out:
# <Axes: xlabel='DepTime', ylabel='ArrTime'>

# %%
avionesS.plot(kind="scatter",x="DepTime",y="ArrDelay")
# Out:
# <Axes: xlabel='DepTime', ylabel='ArrDelay'>

# %%
avionesS.plot(kind="scatter",x="ArrTime",y="ArrDelay")
# Out:
# <Axes: xlabel='ArrTime', ylabel='ArrDelay'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.pairplot(avionesS)

# %%
avionesSD=aviones[["ArrTime","ArrDelay","ArrDelayMinutes","DepTime","DepDelay","DepDelayMinutes","Distance"]]
avionesSD.head()
# Out:
#    ArrTime  ArrDelay  ArrDelayMinutes  DepTime  DepDelay  DepDelayMinutes  \
# 0     1128         3                3     1052        -8                0
# 1     1151        26               26     1130        30               30
# 2     1610        22               22     1540        16               16
# 3     2315        87               87     2220        75               75
# 4     1550         2                2     1530         6                6
#
#    Distance
# 0        31
# 1        31
# 2        31
# 3        67
# 4        31

# %%
avionesSD=aviones[["ArrTime","ArrDelay","ArrDelayMinutes","DepTime","DepDelay","DepDelayMinutes","Distance"]]
avionesSD.head()

# %%
avionesSDs=aviones["Distance"]*aviones["DepDelay"]
avionesSDs.head()
# Out:
# 0    -248
# 1     930
# 2     496
# 3    5025
# 4     186
# dtype: int64

# %%
aviones.boxplot(column=["DepTime"], by="DestCityName")
# Out:
# <Axes: title={'center': 'DepTime'}, xlabel='DestCityName'>

# %%
sns.displot(avionesSD, x="ArrDelay", y="DepDelay", kind="hist",rug=True)

# %%
sns.displot(aviones, x="ArrDelay", y="DepDelay", kind="hist",rug=True)

# %%
pingus=pd.read_csv('/content/penguins_size.csv')

# %%
pingus.sample(100)
# Out:
#        species     island  culmen_length_mm  culmen_depth_mm  \
# 24      Adelie     Biscoe              38.8             17.2
# 251     Gentoo     Biscoe              42.8             14.2
# 188  Chinstrap      Dream              47.6             18.3
# 168  Chinstrap      Dream              50.3             20.0
# 333     Gentoo     Biscoe              51.5             16.3
# ..         ...        ...               ...              ...
# 84      Adelie      Dream              37.3             17.8
# 6       Adelie  Torgersen              38.9             17.8
# 269     Gentoo     Biscoe              45.2             15.8
# 39      Adelie      Dream              39.8             19.1
# 218  Chinstrap      Dream              50.8             19.0
#
#      flipper_length_mm  body_mass_g     sex
# 24               180.0       3800.0    MALE
# 251              209.0       4700.0  FEMALE
# 188              195.0       3850.0  FEMALE
# 168              197.0       3300.0    MALE
# ...

# %%
pingus.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %%
pingusA=pingus[["culmen_length_mm","culmen_depth_mm","flipper_length_mm","body_mass_g"]]
pingusA.head()
# Out:
#    culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# 0              39.1             18.7              181.0       3750.0
# 1              39.5             17.4              186.0       3800.0
# 2              40.3             18.0              195.0       3250.0
# 3               NaN              NaN                NaN          NaN
# 4              36.7             19.3              193.0       3450.0

# %%
pingusA.corr()
# Out:
#                    culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# culmen_length_mm           1.000000        -0.235053           0.656181
# culmen_depth_mm           -0.235053         1.000000          -0.583851
# flipper_length_mm          0.656181        -0.583851           1.000000
# body_mass_g                0.595110        -0.471916           0.871202
#
#                    body_mass_g
# culmen_length_mm      0.595110
# culmen_depth_mm      -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %%
pingusA.plot(kind="scatter",x="body_mass_g",y="flipper_length_mm")
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
pingusA.plot(kind="scatter",x="culmen_depth_mm",y="flipper_length_mm")
# Out:
# <Axes: xlabel='culmen_length_mm', ylabel='flipper_length_mm'>

# %%
pingusA.plot(kind="scatter",x="culmen_length_mm",y="body_mass_g")
# Out:
# <Axes: xlabel='culmen_length_mm', ylabel='body_mass_g'>

# %%
sns.pairplot(pingusA)

# %%
pingusB=pingus.iloc[:,2:6]
pingusB.head()
# Out:
#    culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# 0              39.1             18.7              181.0       3750.0
# 1              39.5             17.4              186.0       3800.0
# 2              40.3             18.0              195.0       3250.0
# 3               NaN              NaN                NaN          NaN
# 4              36.7             19.3              193.0       3450.0

# %%
pingusB.corr()
# Out:
#                    culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# culmen_length_mm           1.000000        -0.235053           0.656181
# culmen_depth_mm           -0.235053         1.000000          -0.583851
# flipper_length_mm          0.656181        -0.583851           1.000000
# body_mass_g                0.595110        -0.471916           0.871202
#
#                    body_mass_g
# culmen_length_mm      0.595110
# culmen_depth_mm      -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %%
import plotly.express as px

# %%
import pandas as pd

# %%
px.scatter_3d(pingus, x="flipper_length_mm", y="body_mass_g", z="culmen_length_mm", color="species")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
