# %%
import pandas as pd

# %%
plantas=pd.read_csv('/content/plant_growth_data.csv')

# %%
plantas.sample(100)
# Out:
#     Soil_Type  Sunlight_Hours Water_Frequency Fertilizer_Type  Temperature  \
# 4       sandy        8.374043       bi-weekly         organic    18.128741
# 15      sandy        8.377637       bi-weekly        chemical    19.954620
# 160      loam        6.348000          weekly            none    22.600000
# 103      loam        7.000000           daily         organic    30.000000
# 100     sandy        8.000000           daily         organic    25.000000
# ..        ...             ...             ...             ...          ...
# 112      loam        8.442000       bi-weekly            none    19.300000
# 61      sandy        4.719192       bi-weekly            none    21.379513
# 1       sandy        4.033133          weekly         organic    28.919484
# 104      clay        6.812000          weekly         organic    26.500000
# 96      sandy        5.119111           daily         organic    21.386273
#
#       Humidity  Growth_Milestone
# 4    63.625923                 0
# ...

# %%
plantas['Soil_Type'].value_counts()
# Out:
# Soil_Type
# clay     67
# sandy    64
# loam     62
# Name: count, dtype: int64

# %%
cambiarSuelo=({'clay':0,'sandy':1,'loam':2})
plantas['Soil_Type']=plantas['Soil_Type'].map(cambiarSuelo)

# %%
plantas
# Out:
#      Soil_Type  Sunlight_Hours Water_Frequency Fertilizer_Type  Temperature  \
# 0            2        5.192294       bi-weekly        chemical    31.719602
# 1            1        4.033133          weekly         organic    28.919484
# 2            2        8.892769       bi-weekly            none    23.179059
# 3            2        8.241144       bi-weekly            none    18.465886
# 4            1        8.374043       bi-weekly         organic    18.128741
# ..         ...             ...             ...             ...          ...
# 188          1        5.652000           daily            none    28.000000
# 189          0        7.528000          weekly        chemical    30.500000
# 190          2        4.934000       bi-weekly            none    24.500000
# 191          1        8.273000           daily         organic    27.900000
# 192          0        6.732000          weekly            none    21.700000
#
#       Humidity  Growth_Milestone
# ...

# %%
plantas['Water_Frequency'].value_counts()
# Out:
# Water_Frequency
# daily        74
# bi-weekly    60
# weekly       59
# Name: count, dtype: int64

# %%
cambiarAgua=({'daily':0,'bi-weekly':1,'weekly':2})
plantas['Water_Frequency']=plantas['Water_Frequency'].map(cambiarAgua)

# %%
plantas
# Out:
#      Soil_Type  Sunlight_Hours  Water_Frequency Fertilizer_Type  Temperature  \
# 0            2        5.192294                1        chemical    31.719602
# 1            1        4.033133                2         organic    28.919484
# 2            2        8.892769                1            none    23.179059
# 3            2        8.241144                1            none    18.465886
# 4            1        8.374043                1         organic    18.128741
# ..         ...             ...              ...             ...          ...
# 188          1        5.652000                0            none    28.000000
# 189          0        7.528000                2        chemical    30.500000
# 190          2        4.934000                1            none    24.500000
# 191          1        8.273000                0         organic    27.900000
# 192          0        6.732000                2            none    21.700000
#
#       Humidity  Growth_Milestone
# ...

# %%
plantas['Fertilizer_Type'].value_counts()
# Out:
# Fertilizer_Type
# none        74
# chemical    65
# organic     54
# Name: count, dtype: int64

# %%
cambiarF=({'none':0,'chemical':1,'organic':2})
plantas['Fertilizer_Type']=plantas['Fertilizer_Type'].map(cambiarF)

# %%
plantas
# Out:
#      Soil_Type  Sunlight_Hours  Water_Frequency  Fertilizer_Type  Temperature  \
# 0            2        5.192294                1                1    31.719602
# 1            1        4.033133                2                2    28.919484
# 2            2        8.892769                1                0    23.179059
# 3            2        8.241144                1                0    18.465886
# 4            1        8.374043                1                2    18.128741
# ..         ...             ...              ...              ...          ...
# 188          1        5.652000                0                0    28.000000
# 189          0        7.528000                2                1    30.500000
# 190          2        4.934000                1                0    24.500000
# 191          1        8.273000                0                2    27.900000
# 192          0        6.732000                2                0    21.700000
#
#       Humidity  Growth_Milestone
# ...

# %%
x=plantas.drop('Growth_Milestone',axis=1)
y=plantas['Growth_Milestone']
y
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      0
#       ..
# 188    0
# 189    1
# 190    0
# 191    1
# 192    0
# Name: Growth_Milestone, Length: 193, dtype: int64

# %%
print(plantas.columns[:-1])
# Out:
# Index(['Soil_Type', 'Sunlight_Hours', 'Water_Frequency', 'Fertilizer_Type',
#        'Temperature', 'Humidity'],
#       dtype='object')

# %%
import seaborn as sns

# %%
sns.pairplot(plantas,hue='Growth_Milestone')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(plantas.drop('Growth_Milestone', axis=1), plantas['Growth_Milestone'], test_size=0.2, random_state=42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((154, 6), (39, 6), (154,), (39,))

# %%
#from sklearn.preprocessing import StandardScaler

# %%
from sklearn.neural_network import MLPClassifier

# %%
mlp=MLPClassifier(hidden_layer_sizes=(100,200,100),solver='adam',max_iter=500)

# %%
mlp.fit(X_train,y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(100, 200, 100), max_iter=500)

# %%
ypredTest=mlp.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
mx=confusion_matrix(y_test,ypredTest)
mx
# Out:
# array([[17,  0],
#        [22,  0]])

# %%
print(classification_report(y_test,ypredTest))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.44      1.00      0.61        17
#            1       0.00      0.00      0.00        22
#
#     accuracy                           0.44        39
#    macro avg       0.22      0.50      0.30        39
# weighted avg       0.19      0.44      0.26        39

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
plantasScaladas=scaler.fit_transform(plantas.drop('Growth_Milestone',axis=1))

# %%
plantasScaladas
# Out:
# array([[ 1.25548011, -1.02433992,  0.09403696,  0.1282895 ,  1.24403863,
#          0.27723828],
#        [ 0.03170404, -1.75092318,  1.30397913,  1.36628319,  0.7196995 ,
#         -0.45056247],
#        [ 1.25548011,  1.29518422,  0.09403696, -1.10970419, -0.35522993,
#         -1.06662074],
#        ...,
#        [ 1.25548011, -1.18624331,  0.09403696, -1.10970419, -0.1078757 ,
#          0.28582143],
#        [ 0.03170404,  0.9067021 , -1.11590522,  1.36628319,  0.52879492,
#          0.90491664],
#        [-1.19207202, -0.05922449,  1.30397913, -1.10970419, -0.63219268,
#         -0.09516024]])

# %%
plantasScaladasDF=pd.DataFrame(plantasScaladas,columns=plantas.columns[:-1])

# %%
plantasScaladasDF
# Out:
#      Soil_Type  Sunlight_Hours  Water_Frequency  Fertilizer_Type  Temperature  \
# 0     1.255480       -1.024340         0.094037         0.128290     1.244039
# 1     0.031704       -1.750923         1.303979         1.366283     0.719700
# 2     1.255480        1.295184         0.094037        -1.109704    -0.355230
# 3     1.255480        0.886734         0.094037        -1.109704    -1.237800
# 4     0.031704        0.970038         0.094037         1.366283    -1.300933
# ..         ...             ...              ...              ...          ...
# 188   0.031704       -0.736188        -1.115905        -1.109704     0.547521
# 189  -1.192072        0.439723         1.303979         0.128290     1.015661
# 190   1.255480       -1.186243         0.094037        -1.109704    -0.107876
# 191   0.031704        0.906702        -1.115905         1.366283     0.528795
# 192  -1.192072       -0.059224         1.303979        -1.109704    -0.632193
#
#      Humidity
# 0    0.277238
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(plantasScaladasDF, plantas['Growth_Milestone'], test_size=0.2, random_state=42,stratify=plantas['Growth_Milestone'])

# %%
X_train.describe()
# Out:
#         Soil_Type  Sunlight_Hours  Water_Frequency  Fertilizer_Type  \
# count  154.000000      154.000000       154.000000       154.000000
# mean    -0.000082       -0.019688         0.023326         0.007706
# std      1.008453        0.998885         0.990207         1.008531
# min     -1.192072       -1.750923        -1.115905        -1.109704
# 25%     -1.192072       -0.876149        -1.115905        -1.109704
# 50%      0.031704        0.003861         0.094037         0.128290
# 75%      1.255480        0.882117         1.303979         1.366283
# max      1.255480        1.908984         1.303979         1.366283
#
#        Temperature    Humidity
# count   154.000000  154.000000
# mean      0.019104    0.025523
# std       1.022831    0.996960
# min      -1.849357   -2.185187
# 25%      -0.831060   -0.652743
# 50%       0.180923    0.166765
# 75%       0.923759    0.879121
# max       1.822754    1.710394

# %%
X_test.describe()
# Out:
#        Soil_Type  Sunlight_Hours  Water_Frequency  Fertilizer_Type  \
# count  39.000000       39.000000        39.000000        39.000000
# mean    0.000325        0.077741        -0.092108        -0.030428
# std     0.992104        1.026562         1.058393         0.991188
# min    -1.192072       -1.745545        -1.115905        -1.109704
# 25%    -1.192072       -0.675373        -1.115905        -1.109704
# 50%     0.031704        0.056737         0.094037         0.128290
# 75%     1.255480        0.929512         1.303979         0.747286
# max     1.255480        1.935250         1.303979         1.366283
#
#        Temperature   Humidity
# count    39.000000  39.000000
# mean     -0.075437  -0.100782
# std       0.927020   1.031508
# min      -1.818565  -2.182009
# 25%      -0.856900  -0.791811
# 50%      -0.032973  -0.103097
# 75%       0.700578   0.769986
# max       1.634468   1.685292

# %%
#mlpScalar=MLPClassifier(hidden_layer_sizes=(200,300,200,100),solver='adam',max_iter=500)
mlpScalar=MLPClassifier(hidden_layer_sizes=(200,200,200),solver='sgd',max_iter=500,random_state=42)

# %%
mlpScalar.fit(X_train,y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(200, 200, 200), max_iter=500, random_state=42,
#               solver='sgd')

# %%
yprediScalar=mlpScalar.predict(X_test)

# %%
mx=confusion_matrix(y_test,yprediScalar)
mx
# Out:
# array([[12,  8],
#        [11,  8]])

# %%
print(classification_report(y_test,yprediScalar))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      0.60      0.56        20
#            1       0.50      0.42      0.46        19
#
#     accuracy                           0.51        39
#    macro avg       0.51      0.51      0.51        39
# weighted avg       0.51      0.51      0.51        39
