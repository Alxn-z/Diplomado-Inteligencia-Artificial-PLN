# %%
import pandas as pd

# %%
vuelos=  pd.read_csv('/content/On_Time_On_Time_Performance_2015_2ac.csv',sep=";")
vuelos.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate UniqueCarrier  \
# 0  2015        1      2          23          1  23/02/2015            AS
# 1  2015        1      2          15          7  15/02/2015            AS
# 2  2015        1      2          22          7  22/02/2015            AS
# 3  2015        1      2          10          2  10/02/2015            OO
# 4  2015        1      2           8          7   8/02/2015            AS
#
#    AirlineID Carrier TailNum  ...  Div4WheelsOff  Div4TailNum  Div5Airport  \
# 0      19930      AS  N796AS  ...            NaN          NaN          NaN
# 1      19930      AS  N708AS  ...            NaN          NaN          NaN
# 2      19930      AS  N706AS  ...            NaN          NaN          NaN
# 3      20304      OO  N912EV  ...            NaN          NaN          NaN
# 4      19930      AS  N765AS  ...            NaN          NaN          NaN
#
#    Div5AirportID Div5AirportSeqID Div5WheelsOn Div5TotalGTime  \
# 0            NaN              NaN          NaN            NaN
# 1            NaN              NaN          NaN            NaN
# 2            NaN              NaN          NaN            NaN
# 3            NaN              NaN          NaN            NaN
# 4            NaN              NaN          NaN            NaN
#
#    Div5LongestGTime Div5WheelsOff  Div5TailNum
# 0               NaN           NaN          NaN
# 1               NaN           NaN          NaN
# 2               NaN           NaN          NaN
# 3               NaN           NaN          NaN
# 4               NaN           NaN          NaN
#
# [5 rows x 109 columns]

# %%
df = vuelos.dropna(axis=1, how='all')
df.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate UniqueCarrier  \
# 0  2015        1      2          23          1  23/02/2015            AS
# 1  2015        1      2          15          7  15/02/2015            AS
# 2  2015        1      2          22          7  22/02/2015            AS
# 3  2015        1      2          10          2  10/02/2015            OO
# 4  2015        1      2           8          7   8/02/2015            AS
#
#    AirlineID Carrier TailNum  ...  DistanceGroup  CarrierDelay  WeatherDelay  \
# 0      19930      AS  N796AS  ...              1           NaN           NaN
# 1      19930      AS  N708AS  ...              1           0.0          26.0
# 2      19930      AS  N706AS  ...              1           0.0           0.0
# 3      20304      OO  N912EV  ...              1           0.0           0.0
# 4      19930      AS  N765AS  ...              1           NaN           NaN
#
#    NASDelay SecurityDelay LateAircraftDelay FirstDepTime  TotalAddGTime  \
# 0       NaN           NaN               NaN          NaN            NaN
# 1       0.0           0.0               0.0          NaN            NaN
# 2       6.0           0.0              16.0          NaN            NaN
# 3      12.0           0.0              75.0          NaN            NaN
# 4       NaN           NaN               NaN          NaN            NaN
#
#   LongestAddGTime  DivAirportLandings
# 0             NaN                   0
# 1             NaN                   0
# 2             NaN                   0
# 3             NaN                   0
# 4             NaN                   0
#
# [5 rows x 64 columns]

# %%
vuelosSeleccionados=vuelos[["ArrTime","ArrDelay","ArrDelayMinutes","DepDelay","DepTime"]]
vuelosSeleccionados.head()
# Out:
#    ArrTime  ArrDelay  ArrDelayMinutes  DepDelay  DepTime
# 0     1128         3                3        -8     1052
# 1     1151        26               26        30     1130
# 2     1610        22               22        16     1540
# 3     2315        87               87        75     2220
# 4     1550         2                2         6     1530

# %%
vuelosSeleccionados[vuelosSeleccionados["DepDelay"]>0]
vuelosSeleccionados.corr()
# Out:
#                   ArrTime  ArrDelay  ArrDelayMinutes  DepDelay   DepTime
# ArrTime          1.000000  0.042296         0.042296  0.072206  0.765966
# ArrDelay         0.042296  1.000000         1.000000  0.955694  0.109110
# ArrDelayMinutes  0.042296  1.000000         1.000000  0.955694  0.109110
# DepDelay         0.072206  0.955694         0.955694  1.000000  0.149854
# DepTime          0.765966  0.109110         0.109110  0.149854  1.000000

# %%
import seaborn as sns

# %%
sns.pairplot(vuelosSeleccionados)

# %%
vuelosSeleccionados.plot(kind='scatter',x='ArrDelay',y='DepDelay')
# Out:
# <Axes: xlabel='ArrDelay', ylabel='DepDelay'>
